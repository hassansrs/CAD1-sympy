# %%
from sympy import *
from sympy.interactive.printing import init_printing
init_printing (use_unicode=True)

# %%
x,y=symbols('x,y')

# %%
f=Function('f')(x**3+2*x-1)

# %%
f.diff()
# Out:
#    2
# 3⋅x  + 2

# %%
diff(f.diff())
# Out:
#                                              2 ⎛  2        ⎞│
#     ⎛ d        ⎞│                  ⎛   2    ⎞  ⎜ d         ⎟│
# 6⋅x⋅⎜───(f(ξ₁))⎟│    3           + ⎝3⋅x  + 2⎠ ⋅⎜────(f(ξ₁))⎟│
#     ⎝dξ₁       ⎠│ξ₁=x  + 2⋅x - 1               ⎜   2       ⎟│    3
#                                                ⎝dξ₁        ⎠│ξ₁=x  + 2⋅x - 1

# %%
f=x**3+2*x-1

# %%
diff(f,x)
# Out:
#    2
# 3⋅x  + 2

# %%
diff(f,x)
# Out:
#    2
# 3⋅x  + 2

# %%
def f(x):
    return x**2+2*x-1

print('first derivative:',diff(diff(f(x))))
# Out:
# ('first derivative:', 2)

# %%
f=atan(x)

# %%
f
# Out:
# atan(x)

# %%
diff(f,x)
# Out:
#   1
# ──────
#  2
# x  + 1

# %%
integrate(diff(f,x))
# Out:
# atan(x)

# %%
w,a=symbols('w,a')

# %%
integrate(x*exp(-a*x)*cos(w*x),(x,0,oo)).simplify()
# Out:
# ⎧       2    2
# ⎪      a  - w               │                 ⎛          2      ⎞│       │
# ⎪     ──────────        for │periodic_argument⎝polar_lift (w), ∞⎠│ = 0 ∧ │peri
# ⎪              2
# ⎪     ⎛ 2    2⎞
# ⎪     ⎝a  + w ⎠
# ⎨
# ⎪∞
# ⎪⌠
# ⎪⎮    -a⋅x
# ⎪⎮ x⋅ℯ    ⋅cos(w⋅x) dx                                           otherwise
# ⎪⌡
# ⎩0
#
#
#              ⎛          2      ⎞│
# odic_argument⎝polar_lift (a), ∞⎠│ < π

# %%
u=symbols('u')

# %%
plot(sin(u),(u,0,pi/2))

# %%
plot(sin(u),(u,0,pi/2))

# %%
plot(x**2,x**3,x**4-x+1,(x,-10,10))

# %%
p1=plot(x**2,x**3,(x,-10,10))

# %%
p2=plot(x**3,(x,-10,10))

# %%
print(p1)
# Out:
# Plot object containing:
# [0]: cartesian line: x**2 for x over (-10.0, 10.0)

# %%
p1.extend(p2)
p2.show()

# %%
c1=2*cos(x)-2+3*sin(2*x)

# %%
p1=plot(cos(x),c1,(x,-pi,pi),legend=True)

# %%
plot(x**2,(x,-5,5),line_color='g',legend=True)

# %%
c1
# Out:
# 3⋅sin(2⋅x) + 2⋅cos(x) - 2

# %%
p1=plot(cos(x),c1,(x,-pi,pi),legend=True, show=False)
p1[0].line_color='green'
p1[1].line_color='black'
p1.show()

# %%
l=[cos(n*x) for n in range (1,4) ]
l
# Out:
# [cos(x), cos(2⋅x), cos(3⋅x)]

# %%
p3=plot(l[0],l[1],l[2],(x,0,2*pi),legend=True,show=False,title='$\cos(nx)$ for n $\in$ [1, 3]')
print p3
# Out:
# Plot object containing:
# [0]: cartesian line: cos(x) for x over (0.0, 6.283185307179586)
# [1]: cartesian line: cos(2*x) for x over (0.0, 6.283185307179586)
# [2]: cartesian line: cos(3*x) for x over (0.0, 6.283185307179586)

# %%
p3[0].line_color='red'
p3[1].line_color='green'
p3[2].line_color='black'
p3.show()

# %%
[plot (cos(n*x),(x,0,2*pi),show=True) for n in range (1,4)]
# Out:
# [<sympy.plotting.plot.Plot at 0xc7ee748>,
#  <sympy.plotting.plot.Plot at 0xc7eec18>,
#  <sympy.plotting.plot.Plot at 0xb38b390>]

# %%
plotting.plot_parametric(cos(u),sin(u),(u,-pi,pi))

# %%
plotting.plot_parametric(cos(u),sin(u),(u,-pi,pi),xlim=(-3,3),ylim=(-3,3))

# %%
t=symbols('t')

# %%
p1=plotting.plot_parametric(cos(t),sin(t),(t,-pi,pi),show=False,legend=True,line_color='r',xlim=(-3,3),ylim=(-3,3))

# %%
p1.extend(plot(x**2-1,show=False))
p1[1].line_color='black'
p1[0].line_color='red'
p1.show()
print p1
# Out:
# Plot object containing:
# [0]: parametric cartesian line: (cos(t), sin(t)) for t over (-3.141592653589793, 3.141592653589793)
# [1]: cartesian line: x**2 - 1 for x over (-10.0, 10.0)
# [2]: cartesian line: x**2 - 1 for x over (-10.0, 10.0)
# [3]: cartesian line: x**2 - 1 for x over (-10.0, 10.0)
# [4]: cartesian line: x**2 - 1 for x over (-10.0, 10.0)
# [5]: cartesian line: x**2 - 1 for x over (-10.0, 10.0)
# [6]: cartesian line: x**2 - 1 for x over (-10.0, 10.0)
# [7]: cartesian line: x**2 - 1 for x over (-10.0, 10.0)
# [8]: cartesian line: x**2 - 1 for x over (-10.0, 10.0)
# [9]: cartesian line: x**2 - 1 for x over (-10.0, 10.0)

# %%
plotting.plot_parametric((cos(u),sin(u)),(u,cos(u)))

# %%
c1=(cos(t),sin(t),(t,0,2*pi))

# %%
print c1
# Out:
# (cos(t), sin(t), (t, 0, 2*pi))

# %%
c1=(cos(t),sin(t),(t,0,2*pi))
c2=(0.35+0.25*cos(t),0.35+0.25*sin(t),(t,0,2*pi))
c3=(-0.35+0.25*cos(t),0.35+0.25*sin(t),(t,0,2*pi))
c4=(cos(t)*0.5,sin(t)*0.5,(t,pi,2*pi))
p=plotting.plot_parametric(c1,c2,c3,c4,show=False)
p.axis=False
p.show()

# %%
x
# Out:
# x

# %%
plotting.plot3d_parametric_line(cos(u),sin(u),u,(u,-5,5))

# %%
plotting.plot3d_parametric_surface(cos(u+t),sin(u-t),u-t,(u,0,5),(t,0,5))

# %%
p1=plot_implicit(Eq(x**2+y**2,5))

# %%
plot_implicit(y>sqrt(x))

# %%
plot_implicit(Eq)
